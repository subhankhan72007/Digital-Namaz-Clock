# %%
import tkinter as tk
from tkinter import Tk,font
root = Tk()
font.families()
# Out:
# ('System',
#  'Terminal',
#  'Fixedsys',
#  'Modern',
#  'Roman',
#  'Script',
#  'Courier',
#  'MS Serif',
#  'MS Sans Serif',
#  'Small Fonts',
#  'TeamViewer15',
#  'Marlett',
#  'Arial',
#  'Arabic Transparent',
#  'Arial Baltic',
#  'Arial CE',
#  'Arial CYR',
#  'Arial Greek',
#  'Arial TUR',
#  'Arial Black',
#  'Bahnschrift Light',
#  'Bahnschrift SemiLight',
#  'Bahnschrift',
#  'Bahnschrift SemiBold',
#  'Bahnschrift Light SemiCondensed',
#  'Bahnschrift SemiLight SemiConde',
#  'Bahnschrift SemiCondensed',
#  'Bahnschrift SemiBold SemiConden',
#  'Bahnschrift Light Condensed',
#  'Bahnschrift SemiLight Condensed',
#  'Bahnschrift Condensed',
#  'Bahnschrift SemiBold Condensed',
#  'Calibri',
#  'Calibri Light',
#  'Cambria',
#  'Cambria Math',
#  'Candara',
#  'Candara Light',
#  'Comic Sans MS',
#  'Consolas',
#  'Constantia',
#  'Corbel',
#  'Corbel Light',
#  'Courier New',
#  'Courier New Baltic',
#  'Courier New CE',
#  'Courier New CYR',
#  'Courier New Greek',
# ...

# %%
import time

# %%
import tkinter as tk
from tkinter import*

win = tk.Tk()
win.title("Mikey")
win.geometry("500x500")

mylable = tk.Label(win,text="Guess The Number Ten",bg="black",fg="Red")
mylable.grid(row=0,column=1)

def click_me1():
    B1.configure(text="looser")
    mylable.configure(text="20")
    
def click_me2():
    B2.configure(text="winner")
    mylable.configure(text="10")
    mylable.configure(bg="blue")
    
def click_me3():
    B3.configure(text="looser")
    mylable.configure(text="30")
    
def click_me4():
    B4.configure(text="looser")
    mylable.configure(text="40")

B1 = Button(win,text="Guess 10",bg="black",fg="Red",command=click_me1 , font=("Algerian",14,"bold","roman"),underline = 1)
B1.grid(row=1,column=1)

B2 = Button(win,text="Guess 10",bg="black",fg="Red",command=click_me2)
B2.grid(row=2,column=1)

B3 = Button(win,text="Guess 10",bg="black",fg="Red",command=click_me3)
B3.grid(row=3,column=1)

B4 = Button(win,text="Guess 10",bg="black",fg="Red",command=click_me4)
B4.grid(row=4,column=1)


    
win.mainloop()

# %%
import tkinter as tk
from tkinter import*
import time

backgroud_color = input("Enter Background Colour:")
text_color = input("Enter Text Colour:")


root = tk.Tk()
root.geometry("800x800")
root.title("Namaz Clock")
root.configure(bg="black")


def tick(time1=""):
    time2=time.strftime("%I : %M : %S")
    clock_frame.configure(text=time2)
    clock_frame.after(20,tick)
    
def Fajar_namaz():
    Fajar.configure(text = "04:45 AM Fajar")
    
def Zuhar_namaz():
    Zuhar.configure(text = "01:00 PM Zuhar")    
    
def Asar_namaz():
    Asar.configure(text = "05:15 PM Asar")
    
def Maghrib_namaz():
    Maghrib.configure(text = "07:10 PM Maghrib")
    
def Isha_namaz():
    Isha.configure(text = "08:28 PM Isha")
    
def Jumma_namaz():
    Jumma.configure(text = "02:00 PM Jumma")
    
    


clock_frame = Label(root,font=("Arial",100,"bold"),bg =backgroud_color,fg = text_color )
clock_frame.grid(row = 0,column = 1)

Fajar = Label(root,font=("Arial",20,"bold"),bg =backgroud_color,fg = text_color )
Fajar.grid(row = 1,column = 1)

Zuhar = Label(root,font=("Arial",20,"bold"),bg =backgroud_color,fg = text_color )
Zuhar.grid(row = 2,column = 1)

Asar = Label(root,font=("Arial",20,"bold"),bg =backgroud_color,fg = text_color )
Asar.grid(row = 3,column = 1)

Maghrib = Label(root,font=("Arial",20,"bold"),bg =backgroud_color,fg = text_color )
Maghrib.grid(row = 4,column = 1)

Isha = Label(root,font=("Arial",20,"bold"),bg =backgroud_color,fg = text_color )
Isha.grid(row = 5,column = 1)

Jumma = Label(root,font=("Arial",20,"bold"),bg =backgroud_color,fg = text_color )
Jumma.grid(row = 6,column = 1)


tick()
Fajar_namaz()
Zuhar_namaz()
Asar_namaz()
Maghrib_namaz()
Isha_namaz()
Jumma_namaz()





root.mainloop()
# Out:
# Enter Background Colour:black
# Enter Text Colour:red

# %%
import tkinter as tk
from tkinter import*
import time

backgroud_color = input("Enter Background Colour:")
text_color = input("Enter Text Colour:")


root = tk.Tk()
root.geometry("800x800")
root.title("Namaz Clock")
root.configure(bg="black")


def tick(time1=""):
    time2=time.strftime("%I : %M : %S")
    clock_frame.configure(text=time2)
    clock_frame.after(20,tick)
    
def Fajar_namaz():
    Fajar.configure(text = "04:45 AM Fajar")
    
def Zuhar_namaz():
    Zuhar.configure(text = "01:00 PM Zuhar")    
    
def Asar_namaz():
    Asar.configure(text = "05:15 PM Asar")
    
def Maghrib_namaz():
    Maghrib.configure(text = "07:10 PM Maghrib")
    
def Isha_namaz():
    Isha.configure(text = "08:28 PM Isha")
    
def Jumma_namaz():
    Jumma.configure(text = "02:00 PM Jumma")
    
    


clock_frame = Label(root,font=("Arial",100,"bold"),bg =backgroud_color,fg = text_color )
clock_frame.pack(fill = "both",expand=1)

Fajar = Label(root,font=("Arial",20,"bold"),bg =backgroud_color,fg = text_color, anchor= "n" )
Fajar.pack(fill = X)

Zuhar = Label(root,font=("Arial",20,"bold"),bg =backgroud_color,fg = text_color, anchor= "n" )
Zuhar.pack(fill = X)

Asar = Label(root,font=("Arial",20,"bold"),bg =backgroud_color,fg = text_color, anchor= "n" )
Asar.pack(fill = X)

Maghrib = Label(root,font=("Arial",20,"bold"),bg =backgroud_color,fg = text_color, anchor= "n" )
Maghrib.pack(fill = X)

Isha = Label(root,font=("Arial",20,"bold"),bg =backgroud_color,fg = text_color, anchor= "n" )
Isha.pack(fill = X)

Jumma = Label(root,font=("Arial",20,"bold"),bg =backgroud_color,fg = text_color, anchor= "n" )
Jumma.pack(fill = X)


tick()
Fajar_namaz()
Zuhar_namaz()
Asar_namaz()
Maghrib_namaz()
Isha_namaz()
Jumma_namaz()





root.mainloop()
# Out:
# Enter Background Colour:black
# Enter Text Colour:red
